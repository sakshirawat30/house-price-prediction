# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
os.chdir(r"C:\Users\admim\Downloads")

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '164922241976960ec2379f8793842aa5b168a_.zip',
#  '165122095024660ec2379f8793842aa5b168a_',
#  '165122534897360ec2379f8793842aa5b168a_.zip',
#  '165408461178060ec2379f8793842aa5b168a_',
#  '165408527393260ec2379f8793842aa5b168a_.zip',
#  '165408581174360ec2379f8793842aa5b168a_.zip',
#  '2-In-class Exercise',
#  '3-In class Exercise',
#  '62c6d7f7e88ed406e8f7ffbc_1659081178601_sakshi test1.sql',
#  '62c6d7f7e88ed406e8f7ffbc_1660646126777_sakshi test 2.ipynb',
#  'Anaconda3-2022.05-Windows-x86_64.exe',
#  'assignmentonpandas',
#  'assignmentonpandas.rar',
#  'Bank_Account_Details.csv',
#  'BANK_ACCOUNT_TRANSACTION.csv',
#  'Bank_customer.csv',
#  'Books _ text book on Stats.pdf',
#  'car data.csv',
#  'Car details v3.csv',
#  'car_done.csv',
#  'CaseStudy (1).zip',
#  'CaseStudy (2).zip',
#  'CaseStudy.zip',
#  'ChromeSetup.exe',
#  'Conditional_statement_loops.ipynb',
#  'corr.xlsx',
#  'Customer.csv',
#  'Customer.xlsx',
#  'Cust_data.csv',
# ...

# %%
df=pd.read_csv("kc_house_data.csv")

# %%
df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
def univariate_cat(x):
    missing=x.isnull().sum()
    unique_cnt=x.nunique()
    unique_cat=list(x.unique())
    print(f"Total missing values : {missing}\n")
    print(f"Total count of unique categories: {unique_cnt}\n")
    print(f"Unique categories :\n{unique_cat}")

# %%
univariate_cat(df["date"])
# Out:
# Total missing values : 0
#
# Total count of unique categories: 372
#
# Unique categories :
# ...

# %%
df.dtypes[df.dtypes=="object"]
# Out:
# date    object
# dtype: object

# %%
def univariate_num(x):
    missing=x.isnull().sum()
    min1=round(x.min(), 2)
    max1=round(x.max(), 2)
    mean=round(x.mean(), 2)
    var=round(x.var(), 2)
    std=round(x.std(),2)
    range1=round(max1-min1, 2)
    q1=round(x.quantile(.25), 2)
    q2=round(x.quantile(.5),2)
    q3=round(x.quantile(.75), 2)
    skew=round( x.skew(), 2)
    kurt=round(x.kurt(), 2)
    myvalue={"missing":missing, "min":min1, "max":max1, "mean":mean,
             "var":var,"std":std, "range":range1,"q1":q1, "q2":q2,"q3":q3,
            "skewness":skew, "kurtosis":kurt}
    sns.histplot(x)
    plt.show()
    sns.boxplot(data=df, y=x)
    plt.show()
    return myvalue

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
univariate_num(df["price"])
# Out:
# {'missing': 0,
#  'min': 75000.0,
#  'max': 7700000.0,
#  'mean': 540088.14,
#  'var': 134782378397.25,
#  'std': 367127.2,
#  'range': 7625000.0,
#  'q1': 321950.0,
#  'q2': 450000.0,
#  'q3': 645000.0,
#  'skewness': 4.02,
#  'kurtosis': 34.59}

# %%
univariate_num(df["id"])
# Out:
# {'missing': 0,
#  'min': 1000102,
#  'max': 9900000190,
#  'mean': 4580301520.86,
#  'var': 8.274629486057814e+18,
#  'std': 2876565571.31,
#  'range': 9899000088,
#  'q1': 2123049194.0,
#  'q2': 3904930410.0,
#  'q3': 7308900445.0,
#  'skewness': 0.24,
#  'kurtosis': -1.26}

# %%
univariate_num(df["bedrooms"])
# Out:
# {'missing': 0,
#  'min': 0,
#  'max': 33,
#  'mean': 3.37,
#  'var': 0.87,
#  'std': 0.93,
#  'range': 33,
#  'q1': 3.0,
#  'q2': 3.0,
#  'q3': 4.0,
#  'skewness': 1.97,
#  'kurtosis': 49.06}

# %%
g=df.describe(percentiles=[.01,.02,.03, .04,.05,.25,.5,.75, .9,.95,.96,.97,.98,.99]).T

# %%
g
# Out:
#                  count          mean           std           min  \
# id             21613.0  4.580302e+09  2.876566e+09  1.000102e+06
# price          21613.0  5.400881e+05  3.671272e+05  7.500000e+04
# bedrooms       21613.0  3.370842e+00  9.300618e-01  0.000000e+00
# bathrooms      21613.0  2.114757e+00  7.701632e-01  0.000000e+00
# sqft_living    21613.0  2.079900e+03  9.184409e+02  2.900000e+02
# sqft_lot       21613.0  1.510697e+04  4.142051e+04  5.200000e+02
# floors         21613.0  1.494309e+00  5.399889e-01  1.000000e+00
# waterfront     21613.0  7.541757e-03  8.651720e-02  0.000000e+00
# view           21613.0  2.343034e-01  7.663176e-01  0.000000e+00
# condition      21613.0  3.409430e+00  6.507430e-01  1.000000e+00
# grade          21613.0  7.656873e+00  1.175459e+00  1.000000e+00
# sqft_above     21613.0  1.788391e+03  8.280910e+02  2.900000e+02
# sqft_basement  21613.0  2.915090e+02  4.425750e+02  0.000000e+00
# ...

# %%
df['date']=df['date'].str[:4]

# %%
df['date']
# Out:
# 0        2014
# 1        2014
# 2        2015
# 3        2014
# 4        2015
#          ...
# 21608    2014
# 21609    2015
# 21610    2014
# 21611    2015
# 21612    2014
# Name: date, Length: 21613, dtype: object

# %%
df['date']=pd.to_numeric(df['date'])

# %%
df["year_old"]=df['date']-df["yr_built"]

# %%
df.drop(columns=['yr_built','date'],inplace=True)

# %%
df.columns
# Out:
# Index(['id', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_renovated', 'zipcode', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15', 'year_old'],
#       dtype='object')

# %%
#df.drop(columns=['id'],inplace=True)

# %%
out=['price', 'bedrooms','bathrooms', 'sqft_living', 'sqft_lot', 'condition', 'grade', 'sqft_above',
       'sqft_basement', 'yr_renovated', 'zipcode', 'lat', 'long',
       'sqft_living15', 'sqft_lot15', 'year_old']
df_out=df[out]

# %%
not_out=['waterfront','view','floors']
df_not_out=df[not_out]

# %%
### Outlier Capping Function - Method -1
def outliers_percentile(x):
    x=x.clip(upper=x.quantile(.99))
#     x=x.clip(lower=x.quantile(.01))
    return x

# %%
df_out1=df_out.apply(outliers_percentile)

# %%
 df_out1.describe(percentiles=[.01,.02,.03, .04,.05,.25,.5,.75, .9,.95,.96,.97,.98,.99]).T
# Out:
#                  count           mean            std         min  \
# price          21613.0  532636.397446  317755.440835  75000.0000
# bedrooms       21613.0       3.365012       0.889130      0.0000
# bathrooms      21613.0       2.109113       0.749363      0.0000
# sqft_living    21613.0    2070.087984     874.081832    290.0000
# sqft_lot       21613.0   13983.659140   27703.785133    520.0000
# condition      21613.0       3.409430       0.650743      1.0000
# grade          21613.0       7.651506       1.157245      1.0000
# sqft_above     21613.0    1780.919539     796.414824    290.0000
# sqft_basement  21613.0     288.171008     429.005284      0.0000
# yr_renovated   21613.0      84.356730     401.460829      0.0000
# zipcode        21613.0   98077.939805      53.505026  98001.0000
# lat            21613.0      47.560031       0.138531     47.1559
# long           21613.0    -122.214489       0.138463   -122.5190
# ...

# %%
df2=pd.concat([df_out, df_not_out], axis=1)

# %%
df2
# Out:
#           price  bedrooms  bathrooms  sqft_living  sqft_lot  condition  grade  \
# 0      221900.0         3       1.00         1180      5650          3      7
# 1      538000.0         3       2.25         2570      7242          3      7
# 2      180000.0         2       1.00          770     10000          3      6
# 3      604000.0         4       3.00         1960      5000          5      7
# 4      510000.0         3       2.00         1680      8080          3      8
# ...         ...       ...        ...          ...       ...        ...    ...
# 21608  360000.0         3       2.50         1530      1131          3      8
# 21609  400000.0         4       2.50         2310      5813          3      8
# 21610  402101.0         2       0.75         1020      1350          3      7
# 21611  400000.0         3       2.50         1600      2388          3      8
# 21612  325000.0         2       0.75         1020      1076          3      7
#
# ...

# %% [markdown]
# ## multicollinerty

# %%
cr=df2.corr()
cr
# Out:
#                   price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# price          1.000000  0.308350   0.525138     0.702035  0.089661
# bedrooms       0.308350  1.000000   0.515884     0.576671  0.031703
# bathrooms      0.525138  0.515884   1.000000     0.754665  0.087740
# sqft_living    0.702035  0.576671   0.754665     1.000000  0.172826
# sqft_lot       0.089661  0.031703   0.087740     0.172826  1.000000
# condition      0.036362  0.028472  -0.124982    -0.058753 -0.008958
# grade          0.667434  0.356967   0.664983     0.762704  0.113621
# sqft_above     0.605567  0.477600   0.685342     0.876597  0.183512
# sqft_basement  0.323816  0.303093   0.283770     0.435043  0.015286
# yr_renovated   0.126434  0.018841   0.050739     0.055363  0.007644
# zipcode       -0.053203 -0.152668  -0.203866    -0.199430 -0.129574
# lat            0.307003 -0.008931   0.024573     0.052529 -0.085683
# long           0.021626  0.129473   0.223042     0.240223  0.229521
# ...

# %%
plt.figure(figsize=(12,6))
sns.heatmap(cr, annot=True, cmap="coolwarm")
plt.show()

# %%
cr1=cr[abs(cr)>.7]

plt.figure(figsize=(10,6))
sns.heatmap(cr1, annot=True, cmap="coolwarm")
plt.show()

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

X = df2[[ 'bedrooms', 'bathrooms' , 'sqft_lot',
       'floors', 'view', 'condition', 'grade', 
        'yr_renovated', 'zipcode', 'lat', 'long',
       'sqft_living15', 'sqft_lot15', 'year_old']]
  
# VIF dataframe
vif_data = pd.DataFrame()
vif_data["feature"] = X.columns
  
# calculating VIF for each feature
vif_data["VIF"] = [variance_inflation_factor(X.values, i)
                          for i in range(len(X.columns))]
  
vif_data.sort_values(by=["VIF"], ascending=False)
# Out:
#           feature           VIF
# 8         zipcode  1.500453e+06
# 10           long  1.323211e+06
# 9             lat  1.367025e+05
# 6           grade  1.249674e+02
# 5       condition  3.468579e+01
# 1       bathrooms  2.299689e+01
# 11  sqft_living15  2.238919e+01
# 0        bedrooms  2.054837e+01
# 3          floors  1.380647e+01
# 13       year_old  6.771416e+00
# 12     sqft_lot15  2.589754e+00
# 2        sqft_lot  2.367457e+00
# 4            view  1.278159e+00
# 7    yr_renovated  1.193016e+00

# %%
sns.histplot(df2["price"])
plt.show()

# %%
from scipy.stats import jarque_bera

# %%
 jarque_bera(df2["price"])
# Out:
# Jarque_beraResult(statistic=1134998.2338603423, pvalue=0.0)

# %%
x=df2[['bedrooms', 'bathrooms' , 'sqft_lot',
       'floors', 'view', 'condition', 'grade', 
        'yr_renovated', 'zipcode', 'lat', 'long',
       'sqft_living15', 'sqft_lot15', 'year_old']]
y=df2["price"]

# %%
from sklearn.model_selection import train_test_split  # Train test split
from sklearn.linear_model import LinearRegression     # Model development
from sklearn import metrics                            # Model evaluate/

# %%
x_train, x_test, y_train, y_test=train_test_split(x,y, test_size=.25, 
                                                  random_state=0)

# %%
reg=LinearRegression()
reg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
# R^2 : How much % of Variance can be explained  by this model/ variables
print("Train R^2 : ", reg.score(x_train, y_train))
# Out:
# Train R^2 :  0.645477119867301

# %%
print("Test R^2 : ", reg.score(x_test, y_test))
# Out:
# Test R^2 :  0.6447483988799825
